# %% [markdown]
# ## Tuplas

# %%
notas = (5, 7, 10)
persona = ("Antonio", 35, True)

ejemplo = (5,)
print(ejemplo)

coordenadas = 4050, 2354
print(coordenadas)
# Out:
# (5,)
# (4050, 2354)

# %%
print(list("abcd"))
print(tuple("abcd"))

colores = ("rojo", "verde", "amarillo", "azul")
colores[1]
# Out:
# ['a', 'b', 'c', 'd']
# ('a', 'b', 'c', 'd')
# 'verde'

# %%
DIAS_SEMANA = ("lunes", "martes", "miércoles", "jueves", "viernes", "sábado", "domingo")

print(DIAS_SEMANA.count("lunes"))
print(DIAS_SEMANA.index("miércoles"))


SERVER_CONFIG = ("localhost", 8080, "mongo", True, "/myDB")
URL = f"{SERVER_CONFIG[0]}:{SERVER_CONFIG[1]}{SERVER_CONFIG[-1]}"

numeros = (1, 2, 3, 4, 5, 6)
print(max(numeros))
print(min(numeros))
print(sum(numeros))

# DESEMPAQUETADO DE TUPLAS
DIAS_SEMANA = ("lunes", "martes", "miércoles", "jueves", "viernes", "sábado", "domingo")

l, m, mi, j, v, s, d = DIAS_SEMANA
print(mi)

COPIA_DIAS_SEMANA = list(DIAS_SEMANA)
COPIA_DIAS_SEMANA.append("mostoles")
DIAS_SEMANA = tuple(COPIA_DIAS_SEMANA)
print(DIAS_SEMANA)
# Out:
# 1
# 2
# 6
# 1
# 21
# miércoles
# ('lunes', 'martes', 'miércoles', 'jueves', 'viernes', 'sábado', 'domingo', 'mostoles')
